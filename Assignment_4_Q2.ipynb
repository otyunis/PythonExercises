# %%
import numpy as np
import pandas as pd
import os# keras module for building LSTM 
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout, GRU, SimpleRNN
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
import keras.utils as ku
import tensorflow.keras.utils as tku
import pandas as pd
import numpy as np
import string, os
import time

# %%
hotel_df = pd.read_csv('Seattle_Hotels.csv', encoding="latin-1")
all_descriptions = list(hotel_df.desc.values)

# %%
len(all_descriptions)
# Out:
# 152

# %%
corpus = [x for x in all_descriptions]
corpus[:1]
# Out:
# ['Located on the southern tip of Lake Union, the Hilton Garden Inn Seattle Downtown hotel is perfectly located for business and leisure. Non-Smoking\nHotel is 100% non-smoking, including e-cigarettes, in all guest rooms and public areas. A fee of up to $250 USD will be assessed for smoking in a non-smoking room. Please ask the Front Desk for locations of designated outdoor smoking areas. Check-in: 4:00 pm. Check-out: 12:00 pm. Cancellation policies may vary depending on the rate or dates of your reservation. Please refer to your reservation confirmation to verify your cancellation policy.\n']

# %%
t = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ', char_level=False, oov_token=None, document_count=0)
t.fit_on_texts(corpus)

# %%
# A dictionary of words and their counts.
print(t.word_counts)

# A dictionary of words and how many documents each appeared in.
print(t.word_docs)

# An integer count of the total number of documents that were used to fit the Tokenizer (i.e. total number of documents)
print(t.document_count)

# A dictionary of words and their uniquely assigned integers.
print(t.word_index)
# Out:
# OrderedDict([('located', 106), ('on', 128), ('the', 1236), ('southern', 1), ('tip', 1), ('of', 526), ('lake', 40), ('union', 31), ('hilton', 11), ('garden', 11), ('inn', 81), ('seattle', 463), ('downtown', 131), ('hotel', 293), ('is', 279), ('perfectly', 6), ('for', 213), ('business', 84), ('and', 1044), ('leisure', 18), ('non', 19), ('smoking', 29), ('100', 10), ('including', 48), ('e', 2), ('cigarettes', 2), ('in', 460), ('all', 104), ('guest', 61), ('rooms', 106), ('public', 9), ('areas', 19), ('a', 610), ('fee', 7), ('up', 46), ('to', 474), ('250', 3), ('usd', 2), ('will', 50), ('be', 49), ('assessed', 2), ('room', 81), ('please', 5), ('ask', 2), ('front', 12), ('desk', 12), ('locations', 2), ('designated', 6), ('outdoor', 24), ('check', 41), ('4', 15), ('00', 19), ('pm', 11), ('out', 36), ('12', 11), ('cancellation', 3), ('policies', 5), ('may', 5), ('vary', 3), ('depending', 2), ('rate', 8), ('or', 159), ('dates', 2), ('your', 184), ('reservation', 5), ('refer', 1), ('confirmation', 1), ('verify', 1), ('policy', 2), ("city's", 5), ('vibrant', 14), ('core', 5), ('sheraton', 8), ('grand', 13), ('provides', 9), ('gateway', 4), ('diverse', 5), ('sights', 1), ('sounds', 1), ('pacific', 41), ('northwest', 41), ('step', 11), ('our', 350), ('doors', 8), ('find', 31), ('gourmet', 1), ('dining', 36), ('bars', 6), ('world', 20), ('class', 12), ('shopping', 31), ('exciting', 6), ('entertainment', 11), ('iconic', 13), ('local', 47), ('attractions', 58), ('pike', 85), ('place', 100), ('market', 94), ('space', 90), ('needle', 63), ('chihuly', 3), ('glass', 10), ('museum', 41), ('as', 114), ('one', 76), ('only', 35), ('seven', 6), ('hotels', 28), ('north', 13), ('america', 3), ('earn', 3), ('esteemed', 1), ('designation', 1), ('guests', 59), ('can', 54), ('book', 11), ('confidently', 1), ('knowing', 1), ('they', 9), ('re', 3), ('receiving', 1), ('highest', 2), ('benchmark', 1), ('product', 1), ('service', 52), ('offerings', 2), ('available', 39), ('experience', 48), ('recently', 7), ('completed', 1), ('multimillion', 1), ('dollar', 1), ('transformation', 1), ('featuring', 26), ('new', 17), ('an', 88), ('expanded', 5), ('club', 17), ('lounge', 20), ('modern', 33), ('meeting', 26), ('event', 28), ('spaces', 11), ('gather', 1), ('stylish', 17), ('lobby', 26), ('enjoy', 90), ('private', 29), ('art', 42), ('collection', 6), ('artists', 2), ('while', 33), ('enjoying', 5), ('favorite', 7), ('beverage', 5), ('from', 218), ('starbucks', 12), ('features', 27), ('several', 5), ('options', 14), ('loulay', 1), ('kitchen', 17), ('bar', 32), ('by', 70), ('james', 1), ('beard', 1), ('award', 13), ('winning', 10), ('chef', 3), ('thierry', 1), ('rautureau', 1), ('not', 23), ('permitted', 6), ('within', 38), ('buildings', 5), ('themselves', 4), ('who', 8), ('smoke', 15), ('are', 142), ('do', 9), ('so', 15), ('outside', 16), ('we', 98), ('committed', 3), ('providing', 5), ('associates', 3), ('with', 278), ('free', 129), ('environment', 6), ('proud', 10), ('boast', 4), ('most', 42), ('comprehensive', 3), ('industry', 6), ('3pm', 2), ('12pm', 5), ('heart', 35), ('crowne', 5), ('plaza', 4), ('offers', 42), ('exceptional', 5), ('blend', 3), ('style', 27), ('comfort', 24), ('you', 215), ('ll', 1), ('notice', 1), ('cool', 5), ('comfortable', 30), ('unconventional', 1), ('touches', 4), ('that', 59), ('set', 4), ('us', 21), ('apart', 1), ('soon', 3), ('inside', 7), ('marvel', 2), ('at', 226), ('stunning', 7), ('views', 39), ('city', 59), ('lights', 4), ('relaxing', 12), ('sleep', 6), ('advantage', 12), ('beds', 15), ('complimentary', 60), ('wireless', 11), ('internet', 29), ('throughout', 9), ('amenities', 59), ('help', 11), ('relax', 24), ('like', 43), ('temple', 1), ('spa', 12), ('tight', 1), ('amenity', 1), ('kits', 1), ('lavender', 1), ('spray', 1), ('lotions', 1), ('rejuvenate', 1), ('unwind', 8), ('invigorating', 1), ('workout', 6), ('24', 38), ('hour', 28), ('fitness', 40), ('center', 146), ('get', 10), ('suggestions', 1), ('expert', 2), ('concierge', 3), ( ...
# defaultdict(<class 'int'>, {'non': 15, 'designated': 6, 'fee': 6, 'confirmation': 1, '12': 10, 'smoking': 19, 'on': 77, 'hilton': 9, 'up': 33, 'please': 4, 'verify': 1, 'inn': 35, 'tip': 1, 'cancellation': 2, 'leisure': 16, 'garden': 9, 'vary': 3, 'your': 88, 'policy': 2, 'areas': 17, 'the': 148, 'union': 15, 'e': 2, 'will': 31, 'check': 24, 'lake': 19, 'locations': 2, 'is': 122, 'be': 38, 'usd': 2, 'rate': 8, 'out': 33, 'downtown': 84, 'perfectly': 6, '4': 12, 'of': 134, 'or': 83, 'a': 141, 'ask': 2, 'seattle': 129, 'public': 9, 'including': 35, 'in': 139, 'business': 
': 137, 'friendly': 138, 'walk': 139, 'each': 140, 'every': 141, 'queen': 142, 'features': 143, 'style': 144, 'where': 145, 'speed': 146, 'full': 147, 'featuring': 148, 'meeting': 149, 'lobby': 150, 'you\x92re': 151, 'district': 152, '\x96': 153, 'two': 154, 'street': 155, 'light': 156, 'work': 157, 'suite': 158, 'travel': 159, 'hot': 160, 'wifi': 161, 'such': 162, 'tacoma': 163, 'family': 164, 'outdoor': 165, 'comfort': 166, 'relax': 167, 'historic': 168, 'not': 169, 'convention': 170, 'distance': 171, 'need': 172, 'miles': 173, 'its': 174, 'living': 175, 'sea': 176, 'travelers': 177, "seattle's": 178, 'us': 179, 'designed': 180, 'walking': 181, 'visit': 182, 'blocks': 183, 'some': 184, 'whether': 185, 'other': 186, 'flat': 187, 'hill': 188, 'km': 189, 'world': 190, 'lounge': 191, 'sound': 192, 'offering': 193, 'explore': 194, 'you\x92ll': 195, 'steps': 196, 'welcome': 197, 'next': 198, '5': 199, 'feature': 200, 'non': 201, 'areas': 202, '00': 203, 'here': 204, 'safeco': 205, 'than': 206, 'if': 207, 'rail': 208, 'first': 209, "you'll": 210, 'south': 211, 'include': 212, 'wa': 213, 'site': 214, 'sure': 215, 'motel': 216, 'leisure': 217, 'luxury': 218, 'off': 219, 'morning': 220, 'building': 221, 'amazon': 222, 'property': 223, 'minute': 224, 'new': 225, 'club': 226, 'stylish': 227, 'kitchen': 228, 'guestrooms': 229, 'top': 230, 'fresh': 231, 'short': 232, 'everything': 233, 'equipped': 234, 'food': 235, 'screen': 236, 'through': 237, 'outside': 238, 'come': 239, 'emerald': 240, 'nearby': 241, 'centurylink': 242, 'puget': 243, 'meetings': 244, 'feet': 245, 'across': 246, 'music': 247, 'indoor': 248, 'convenience': 249, 'few': 250, 'convenient': 251, 'capitol': 252, '4': 253, 'smoke': 254, 'so': 255, 'beds': 256, 'west': 257, 'avenue': 258, 'see': 259, 'pioneer': 260, 'hyatt': 261, 'famous': 262, 'extended': 263, 'both': 264, 'unique': 265, 'tv': 266, 'anne': 267, 'fun': 268, 'traveling': 269, 'flight': 270, 'vibrant': 271, 'options': 272, 'mile': 273, 'which': 274, 'situated': 275, 'signature': 276, 'urban': 277, 'shops': 278, 'right': 279, 'bay': 280, 'plus': 281, 'no': 282, 'around': 283, 'tac': 284, 'start': 285, 'events': 286, 'gr ...

# %%
print('Found %s unique tokens.' % len(t.word_index))
# Out:
# Found 3428 unique tokens.

# %%
# Tokenization
t = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ', char_level=False, oov_token=None, document_count=0)

def get_sequence_of_tokens(corpus):
    t.fit_on_texts(corpus)
    total_words = len(t.word_index) + 1
    
    input_sequences = []
    for line in corpus:
        token_list = t.texts_to_sequences([line])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)
            
    return input_sequences, total_words
input_sequences, total_words = get_sequence_of_tokens(corpus)

# %%
input_sequences[:10]
# Out:
# [[24, 22],
#  [24, 22, 1],
#  [24, 22, 1, 1750],
#  [24, 22, 1, 1750, 1751],
#  [24, 22, 1, 1750, 1751, 4],
#  [24, 22, 1, 1750, 1751, 4, 83],
#  [24, 22, 1, 1750, 1751, 4, 83, 114],
#  [24, 22, 1, 1750, 1751, 4, 83, 114, 1],
#  [24, 22, 1, 1750, 1751, 4, 83, 114, 1, 334],
#  [24, 22, 1, 1750, 1751, 4, 83, 114, 1, 334, 335]]

# %%
total_words
# Out:
# 3429

# %%
# pad sequences 
def generate_padded_sequences(input_sequences):
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen = max_sequence_len, padding = 'pre'))
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    label = tku.to_categorical(label, num_classes = total_words)
    
    return predictors, label, max_sequence_len

predictors, label, max_sequence_len = generate_padded_sequences(input_sequences)

# %%
def create_model(max_sequence_len, total_words, model_type):
    model = Sequential()
    
    # Add Input Embedding Layer
    model.add(Embedding(total_words, 10, input_length=max_sequence_len - 1))
    
    # Add Hidden Layer 1 - LSTM Layer
    if model_type == 'LSTM':
        model.add(LSTM(100))
    elif model_type == 'GRU':
        model.add(GRU(100))
    elif model_type == 'SimpleRNN':
        model.add(SimpleRNN(100))
    
    model.add(Dropout(0.1))
    
    # Add Output Layer
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    return model

model_LSTM = create_model(max_sequence_len, total_words, 'LSTM')
model_LSTM.summary()

model_GRU = create_model(max_sequence_len, total_words, 'GRU')
model_GRU.summary()

model_SimpleRNN = create_model(max_sequence_len, total_words, 'SimpleRNN')
model_SimpleRNN.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 505, 10)           34290
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               44400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3429)              346329
# =================================================================
# Total params: 425,019
# Trainable params: 425,019
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 505, 10)           34290
# _________________________________________________________________
# gru_1 (GRU)                  (None, 100)               33600
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3429)              346329
# =================================================================
# Total params: 414,219
# Trainable params: 414,219
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 505, 10)           34290
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 100)               11100
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3429)              346329
# =================================================================
# Total params: 391,719
# Trainable params: 391,719
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
start = time.time()
model_LSTM.fit(predictors, label, epochs=epochs, verbose=5)
end = time.time()
print('LSTM Training Time:',end-start)
start = time.time()
model_GRU.fit(predictors, label, epochs=epochs, verbose=5)
end = time.time()
print('GRU Training Time:',end-start)
start = time.time()
model_SimpleRNN.fit(predictors, label, epochs=epochs, verbose=5)
end = time.time()
print('SimpleRNN Training Time:',end-start)
# Out:
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# LSTM Training Time: 677.3964171409607
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# GRU Training Time: 695.9771780967712
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# SimpleRNN Training Time: 10716.489327192307

# %%
def generate_text(seed_text, next_words, model, max_seq_len):
    for _ in range(next_words):
        token_list = t.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')
        
        #predicted = model.predict(token_list, verbose=0)
        predicted = np.argmax(model.predict(token_list), axis=-1)
        
        output_word = ''
        
        for word,index in t.word_index.items():
            if index == predicted:
                output_word = word
                break
                
        seed_text = seed_text + " " + output_word
        
    return seed_text.title()

# %%
print(generate_text("hilton seattle downtown", 100, model_LSTM, max_sequence_len))
print()
print(generate_text("best western seattle airport hotel", 200, model_LSTM, max_sequence_len))
print()
print(generate_text('located in the heart of downtown seattle', 300, model_LSTM, max_sequence_len))
# Out:
